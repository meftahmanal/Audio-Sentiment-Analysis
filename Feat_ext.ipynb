# %%
import librosa
import librosa.display
import json
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import pandas as pd
import seaborn as sns
import glob 
import os
import pickle
import IPython.display as ipd

# %%
# %cd /content/drive/MyDrive/kaggle
# Out:
# /content/drive/MyDrive/kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ref = pd.read_csv("/content/drive/MyDrive/kaggle/Data_path.csv")
ref.head()
# Out:
#        labels source                                          path
# 0  male_angry  SAVEE  /content/drive/MyDrive/kaggle/ALL/DC_a01.wav
# 1  male_angry  SAVEE  /content/drive/MyDrive/kaggle/ALL/DC_a13.wav
# 2  male_angry  SAVEE  /content/drive/MyDrive/kaggle/ALL/DC_a08.wav
# 3  male_angry  SAVEE  /content/drive/MyDrive/kaggle/ALL/DC_a07.wav
# 4  male_angry  SAVEE  /content/drive/MyDrive/kaggle/ALL/DC_a05.wav

# %%
df = pd.DataFrame(columns=['feature'])

# %%
counter=0
for index,path in enumerate(ref.path):
    X, sample_rate = librosa.load(path
                                  , res_type='kaiser_fast'
                                  ,duration=2.5
                                  ,sr=44100
                                  ,offset=0.5)
    sample_rate = np.array(sample_rate)
    
    # mean as the feature.  
    mfccs = np.mean(librosa.feature.mfcc(y=X, 
                                        sr=sample_rate, 
                                        n_mfcc=13),
                    axis=0)
    df.loc[counter] = [mfccs]
    counter=counter+1   

# Check a few records to make sure its processed successfully
print(len(df))
df.head()
# Out:
# 12162
#                                              feature
# 0  [-11.113934, -7.2157545, -6.21919, -5.9265437,...
# 1  [-23.959705, -23.641237, -23.807817, -23.63339...
# 2  [-27.551817, -25.248302, -22.91287, -23.200481...
# 3  [-25.975302, -22.8251, -21.225157, -20.821096,...
# 4  [-22.458635, -22.467833, -25.884357, -27.82704...

# %%
df = pd.concat([ref,pd.DataFrame(df['feature'].values.tolist())],axis=1)
df[:5]
# Out:
#        labels source  ...        214        215
# 0  male_angry  SAVEE  ...  -2.509089   1.964607
# 1  male_angry  SAVEE  ...  -9.823798  -9.753226
# 2  male_angry  SAVEE  ... -26.979715 -27.205202
# 3  male_angry  SAVEE  ...        NaN        NaN
# 4  male_angry  SAVEE  ... -25.902941 -25.589962
#
# [5 rows x 219 columns]

# %%
df=df.fillna(0)
print(df.shape)
df[:5]
# Out:
# (12162, 219)
#        labels source  ...        214        215
# 0  male_angry  SAVEE  ...  -2.509089   1.964607
# 1  male_angry  SAVEE  ...  -9.823798  -9.753226
# 2  male_angry  SAVEE  ... -26.979715 -27.205202
# 3  male_angry  SAVEE  ...   0.000000   0.000000
# 4  male_angry  SAVEE  ... -25.902941 -25.589962
#
# [5 rows x 219 columns]

# %%
df.to_csv("Data_path_features.csv",index=False)

# %%
db = pd.read_csv("/content/drive/MyDrive/kaggle/Data_path_features.csv")

# %%
db
# Out:
#                labels source  ...        214        215
# 0          male_angry  SAVEE  ...  -2.509089   1.964607
# 1          male_angry  SAVEE  ...  -9.823798  -9.753226
# 2          male_angry  SAVEE  ... -26.979715 -27.205202
# 3          male_angry  SAVEE  ...   0.000000   0.000000
# 4          male_angry  SAVEE  ... -25.902941 -25.589962
# ...               ...    ...  ...        ...        ...
# 12157  female_disgust  CREMA  ...   0.000000   0.000000
# 12158     female_fear  CREMA  ...   0.000000   0.000000
# 12159    female_happy  CREMA  ...   0.000000   0.000000
# 12160  female_neutral  CREMA  ...   0.000000   0.000000
# 12161      female_sad  CREMA  ...   0.000000   0.000000
#
# [12162 rows x 219 columns]

# %%
db.isnull().values.sum()
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['path','labels','source'],axis=1)
                                                    , df.labels
                                                    , test_size=0.25
                                                    , shuffle=True
                                                    , random_state=42
                                                   )

# Lets see how the data present itself before normalisation 
X_train[150:160]
# Out:
#              0          1          2    ...        213        214        215
# 4950  -18.611181 -17.616535 -18.411484  ... -24.612816 -24.153774 -22.703135
# 3860  -13.719338 -16.901081 -23.111773  ...   0.000000   0.000000   0.000000
# 9761   -1.533946  -4.030604  -9.614023  ...   0.000000   0.000000   0.000000
# 7620   -4.531078  -3.933793  -4.567834  ...   0.000000   0.000000   0.000000
# 11586 -20.621704 -21.587505 -20.563646  ...   0.000000   0.000000   0.000000
# 7914  -17.514992 -18.551868 -17.043013  ...   0.000000   0.000000   0.000000
# 9513  -18.740368 -18.824934 -16.149492  ...   0.000000   0.000000   0.000000
# 5835  -19.066853 -18.328382 -17.710285  ...   0.000000   0.000000   0.000000
# 5389  -20.760588 -20.047140 -18.961346  ...   0.000000   0.000000   0.000000
# 11222 -18.252928 -17.727369 -19.222475  ... -17.512487 -17.008547 -18.195280
#
# [10 rows x 216 columns]

# %%
# Lts do data normalization 
mean = np.mean(X_train, axis=0)
std = np.std(X_train, axis=0)

X_train = (X_train - mean)/std
X_test = (X_test - mean)/std

# Check the dataset now 
X_train[150:160]
# Out:
#             0         1         2    ...       213       214       215
# 4950   0.187061  0.303830  0.437761  ... -0.985900 -0.969144 -0.878309
# 3860   0.529310  0.355835  0.088777  ...  0.500577  0.495529  0.491118
# 9761   1.381837  1.291359  1.090949  ...  0.500577  0.495529  0.491118
# 7620   1.172149  1.298396  1.465616  ...  0.500577  0.495529  0.491118
# 11586  0.046399  0.015190  0.277969  ...  0.500577  0.495529  0.491118
# 7914   0.263754  0.235843  0.539367  ...  0.500577  0.495529  0.491118
# 9513   0.178023  0.215995  0.605708  ...  0.500577  0.495529  0.491118
# 5835   0.155181  0.252088  0.489823  ...  0.500577  0.495529  0.491118
# 5389   0.036682  0.127156  0.396935  ...  0.500577  0.495529  0.491118
# 11222  0.212126  0.295774  0.377547  ... -0.557080 -0.535861 -0.606400
#
# [10 rows x 216 columns]

# %%
max_data = np.max(X_train)
min_data = np.min(X_train)
X_train = (X_train-min_data)/(max_data-min_data+1e-6)
X_train =  X_train-0.5

max_data = np.max(X_test)
min_data = np.min(X_test)
X_test = (X_test-min_data)/(max_data-min_data+1e-6)
X_test =  X_test-0.5

X_train[150:160]
# Out:
#             0         1         2    ...       213       214       215
# 4950   0.196711  0.243376  0.229571  ...  0.171467  0.164676  0.136014
# 3860   0.246526  0.251038  0.179595  ...  0.494098  0.472364  0.405265
# 9761   0.370613  0.388876  0.323110  ...  0.494098  0.472364  0.405265
# 7620   0.340092  0.389913  0.376764  ...  0.494098  0.472364  0.405265
# 11586  0.176237  0.200848  0.206688  ...  0.494098  0.472364  0.405265
# 7914   0.207874  0.233359  0.244121  ...  0.494098  0.472364  0.405265
# 9513   0.195395  0.230434  0.253622  ...  0.494098  0.472364  0.405265
# 5835   0.192071  0.235752  0.237027  ...  0.494098  0.472364  0.405265
# 5389   0.174823  0.217345  0.223725  ...  0.494098  0.472364  0.405265
# 11222  0.200359  0.242189  0.220948  ...  0.264540  0.255697  0.189475
#
# [10 rows x 216 columns]

# %% [markdown]
# German Dataset

# %%
EmoDB = "/content/drive/MyDrive/kaggle/EmoDB/wav/"

# %%
dir_list = os.listdir(EmoDB)

file_emotion = []
file_path = []
gender = []
for part in dir_list:       
        if part[0:2] in '0310111215':          
                temp = 'female'
        else: 
                temp = 'male'
        gender.append(temp)
        if part[5] == 'W':
                file_emotion.append('angry')
        elif part[5] == 'L':
                 file_emotion.append('bored')
        elif part[5] == 'E':
               file_emotion.append('disgust')
        elif part[5] == 'A':
                file_emotion.append('fear')
        elif part[5] == 'F':
                file_emotion.append('happy')
        elif part[5] == 'T':
                        file_emotion.append('sad')
        elif part[5] == 'N':
                file_emotion.append('neutral')
        else:
                file_emotion.append('Unknown')
        file_path.append(EmoDB + part)

emotion_df = pd.DataFrame(file_emotion, columns=['emotions'])
gender_df = pd.DataFrame(gender, columns=['gender'])
path_df = pd.DataFrame(file_path, columns=['path'])

df_emo = pd.concat([emotion_df,gender_df, path_df], axis=1)

df_emo.emotions.value_counts()
# Out:
# angry      127
# bored       81
# neutral     79
# happy       71
# fear        69
# sad         62
# disgust     46
# Name: emotions, dtype: int64

# %%
df_emo.head()
# Out:
#   emotions  gender                                               path
# 0    happy  female  /content/drive/MyDrive/kaggle/EmoDB/wav/03a02F...
# 1  neutral  female  /content/drive/MyDrive/kaggle/EmoDB/wav/03a01N...
# 2    angry  female  /content/drive/MyDrive/kaggle/EmoDB/wav/03a02W...
# 3      sad  female  /content/drive/MyDrive/kaggle/EmoDB/wav/03a02T...
# 4    angry  female  /content/drive/MyDrive/kaggle/EmoDB/wav/03a01W...

# %%
emo_feat = pd.DataFrame(columns=['feature'])

# %%
counter=0
for index,path in enumerate(df_emo.path):
    X, sample_rate = librosa.load(path
                                  , res_type='kaiser_fast'
                                  ,duration=2.5
                                  ,sr=44100
                                  ,offset=0.5)
    sample_rate = np.array(sample_rate)
    
    # mean as the feature. Could do min and max etc as well. 
    mfccs = np.mean(librosa.feature.mfcc(y=X, 
                                        sr=sample_rate, 
                                        n_mfcc=13),
                    axis=0)
    emo_feat.loc[counter] = [mfccs]
    counter=counter+1   

# Check a few records to make sure its processed successfully
print(len(emo_feat))
emo_feat.head()
# Out:
# 535
#                                              feature
# 0  [-6.808378, -9.853182, -18.269833, -19.185545,...
# 1  [-1.2132392, -2.3784957, -5.90626, -7.551967, ...
# 2  [-1.7612203, -5.110916, -17.499926, -12.728250...
# 3  [4.5023403, 3.9716506, 3.5952356, 3.5978758, 3...
# 4  [-0.15411714, -4.184052, -20.010956, -20.82891...

# %%
df2 = pd.concat([df_emo,pd.DataFrame(emo_feat['feature'].values.tolist())],axis=1)
df2[:5]
# Out:
#   emotions  gender  ... 214  215
# 0    happy  female  ... NaN  NaN
# 1  neutral  female  ... NaN  NaN
# 2    angry  female  ... NaN  NaN
# 3      sad  female  ... NaN  NaN
# 4    angry  female  ... NaN  NaN
#
# [5 rows x 219 columns]

# %%
df2.head()
# Out:
#   emotions  gender  ... 214  215
# 0    happy  female  ... NaN  NaN
# 1  neutral  female  ... NaN  NaN
# 2    angry  female  ... NaN  NaN
# 3      sad  female  ... NaN  NaN
# 4    angry  female  ... NaN  NaN
#
# [5 rows x 219 columns]

# %%
df2.isnull().values.any()
# Out:
# True
